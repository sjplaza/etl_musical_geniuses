# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
#store file path

top_artist = "spotify_global.csv"

#import data into pd df
top_artist_df = pd.read_csv(top_artist, low_memory=False)
top_artist_df
# Out:
#      Country    Rank                Track_id     Streams  \
# 0     global     1.0  25sgk305KZfyuqVBQIahim  1166185736
# 1     global     2.0  2Fxmhks0bxGSBdJ92vM42m  1052358787
# 2     global     3.0  6ocbgoVGwYJhOv1GgI9NsF   789094044
# 3     global     4.0  1rgnBhdG2JDFTbYkYRZAku   764208309
# 4     global     5.0  6v3KW9xbzN5yKLt9YKDYA2   763064359
# ...      ...     ...                     ...         ...
# 1712  global  1713.0  27SdWb2rFzO6GWiYDBTD9j      554971
# 1713  global  1714.0  0kLA41xkWzzYzMIEGFuDkP      544655
# 1714  global  1715.0  79hJaqmVdohltPBNN6BULM      536886
# 1715  global  1716.0  7rLegaz7zKB6EtDNzcslKE      536447
# 1716  global  1717.0  0kCqaybZgYcLYxzZymmBoc      524230
#
#                                              Track Name              Artist  \
# 0                                      Sweet but Psycho             Ava Max
# 1                                               bad guy       Billie Eilish
# ...

# %%
#filter only the columns you want to use
filtered_df = top_artist_df[["Artist", "Track Name", "Streams"]]
filtered_df.head(50)
# Out:
#                  Artist                                     Track Name  \
# 0               Ava Max                               Sweet but Psycho
# 1         Billie Eilish                                        bad guy
# 2         Ariana Grande                                        7 rings
# 3           Tones and I                                   Dance Monkey
# 4          Shawn Mendes                                       Señorita
# 5          Daddy Yankee                                      Con Calma
# 6             Lady Gaga                                        Shallow
# 7         Lewis Capaldi                              Someone You Loved
# 8            Marshmello                                        Happier
# 9           Post Malone                                           Wow.
# 10               Halsey                                     Without Me
# 11           Pedro Capó                                  Calma - Remix
# ...

# %%
# need second csv file
top_artist2 = "music_data.csv"

#import data into pd df
top_artist2_df = pd.read_csv(top_artist2, low_memory=False)
top_artist2_df
# Out:
#         acousticness                                   artists  danceability  \
# 0             0.9950                       ['Carl Woitschach']         0.708
# 1             0.9940  ['Robert Schumann', 'Vladimir Horowitz']         0.379
# 2             0.6040                   ['Seweryn Goszczyński']         0.749
# 3             0.9950                      ['Francisco Canaro']         0.781
# 4             0.9900  ['Frédéric Chopin', 'Vladimir Horowitz']         0.210
# ...              ...                                       ...           ...
# 169904        0.1730                    ['DripReport', 'Tyga']         0.875
# 169905        0.0167        ['Leon Bridges', 'Terrace Martin']         0.719
# 169906        0.5380                     ['Kygo', 'Oh Wonder']         0.514
# 169907        0.0714             ['Cash Cash', 'Andy Grammer']         0.646
# 169908        0.1090                        ['Ingrid Andress']         0.512
#
# ...

# %%
#filter data from columns you need only
filtered_df = top_artist2_df[['artists', 'name', 'popularity', 'year']]
data_from_2019 = filtered_df.loc[filtered_df['year'] == 2019]
data_from_2019.sort_values('popularity', ascending=False).head(50)
# Out:
#                                                   artists  \
# 87840                                     ['Roddy Ricch']
# 87844                          ['BENEE', 'Gus Dapperton']
# 87852                             ['Surf Mesa', 'Emilee']
# 87858                                     ['Tones And I']
# 87845                                        ['Doja Cat']
# 87850                                        ['Dua Lipa']
# 87842                                        ['Surfaces']
# 87843                                  ['Arizona Zervas']
# 87909                          ['KAROL G', 'Nicki Minaj']
# 87890                                    ['Topic', 'A7S']
# 87856                                   ['Lewis Capaldi']
# 87847                                    ['Travis Scott']
# 87863                                   ['Billie Eilish']
# 87865                                        ['Maroon 5']
# 97637                                          ['Regard']
# ...

# %%
# Create engine
engine = create_engine('postgresql://postgres:Sarahruth14@localhost:5432/top_artistdb')
conn = engine.connect()

# %%
engine.table_names()
# Out:
# ['spotify_global']

# %%
filtered_df.to_sql(name='spotify_global', con=engine, if_exists='replace', index=False)

# %%
pd.read_sql_query('select * from spotify_global', con=engine).tail()
# Out:
#                                    artists                            name  \
# 169904              ['DripReport', 'Tyga']   Skechers (feat. Tyga) - Remix
# 169905  ['Leon Bridges', 'Terrace Martin']  Sweeter (feat. Terrace Martin)
# 169906               ['Kygo', 'Oh Wonder']                How Would I Know
# 169907       ['Cash Cash', 'Andy Grammer']                     I Found You
# 169908                  ['Ingrid Andress']           More Hearts Than Mine
#
#         popularity  year
# 169904          75  2020
# 169905          64  2020
# 169906          70  2020
# 169907          70  2020
# 169908          65  2020
